# %% [markdown]
# # Demo Notebook
# Welcome in your first Jupyter Notebook in Python.  We will start with short Python and Jupyter notebook introduction.
#
#
# **Python** is an *interpreted language*. Interpreted languages do not need to be compiled to run. A program called an interpreter (kernel/console) runs Python code on almost any kind of computer. This means that a programmer can change the code and quickly see the results. This also means Python is slower than a compiled language like C, because it is not running machine code directly.
#   <img src="https://tutorialspoint.com/jupyter/images/jupyter_notebook_kernel_indicator.jpg">
# <center>You can see the status of the kernel at the background by circle indicator in the top-right corner.</center>
#
# **Jupyter Notebooks** and Spyder are using special enhaced version of Python interpreter called **IPython**. This version contains extra commands for debugging and fixing problems. IPython supports commands:
# - history: Shows history of executed commands in kernel
# - variable_name? and variable_name??: Returns detailed infromation about object in memory
# - Many more: https://www.tutorialspoint.com/jupyter/jupyter_quick_guide.htm

# %% [markdown]
# ## Run your fist code
# **Hint:** Press Shift + Enter to run the selected cell.

# %%
print("Hello Minerva! This is my first code cell!")

# %%
print("This is print area")
print("Print area can large as you need.")
print("Yes, this is still in print area")
"Hello!"
"This is output area"
"In output area, only last output is displayed"

# %%
12+35*2

# %%
my_large_variable = 2**2018
print(my_large_variable)

# %% [markdown]
# ## Meet your Kernel

# %%
my_favourite_variable = "Minerva Schools at KGI"
print(my_favourite_variable)

# %%
my_other_number = 2018**20
print(my_other_number)

# %%
print(2019**150000)

# %%
print("I love my Kernel")

# %%
print("Hello Kernel!")

# %%
print(345 + 12000)

# %% [markdown]
# ### My code is running too long

# %%
while True:
    print("Hello Kernel!")

# %%
print("done")

# %% [markdown]
# ### I can't stop this

# %%
print(10**100000000000)

# %%
print("done")

# %%
print(my_favourite_variable)

# %% [markdown]
# ## Kernel remembers nearly everything

# %%
print("My most favourite variable is:", my_favourite_variable)
print("My large variable is:", my_large_variable)
print("My other number is:", my_other_number)

# %% [markdown]
# ### Changing the variables

# %%
my_other_number = 2

# %%
print("My most favourite variable is:", my_favourite_variable)
print("My large variable is:", my_large_variable)
print("My other number is:", my_other_number)

# %%
my_favourite_variable = "Python 3"

# %% [markdown]
# ## Customize the notebook

# %% [markdown]
# ![ersme2p.jpg](attachment:ersme2p.jpg)

# %% [markdown]
# delete me!

# %% [markdown]
# ...
#
#
#
#
#
# ...
#
#
#
#
# ...
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
# ...
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
# ...

# %% [markdown]
# ![thank%20you%20python.jpg](attachment:thank%20you%20python.jpg)
